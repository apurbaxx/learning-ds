# %% [markdown]
# Probability Distributions describe how the probabilities of different outcomes are distributed over the sample space of a random variable
#
# - Discrete Probability Distributions
# - Continious Probabilirty Distributionst

# %% [markdown]
# Probability Distribution Functions is the mathematical function that gives probabilities of occurrence of different possible outcomes for an experiment

# %% [markdown]
# Probability Distribution is of 3 types
#
# - Probability Density Function
# - Probability Mass Function
# - Cumulative Density Function

# %% [markdown]
# Normal Distribution Function

# %% [markdown]
# It is known as the Gaussian Distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data for data from the mean. In graph form, normal; distribution will appear as bell curve

# %% [markdown]
# - Standard Normal Distribution:
#     - The standard Normal distribution, also knows as the Z distribution or the Z-Score is a special case of the Normal Distribution
#     - Mean is 0 and standard deviation is 1 in this distribution curve
